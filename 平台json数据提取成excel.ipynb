# %%
# _*_ coding: utf-8 _*_
import requests
from bs4 import BeautifulSoup

def get_links(search_number,filename):
    base_url = 'http://222.73.69.171:21035'
    url = base_url + "/" + search_number
    print (url)
    wb_data = requests.get(url)
    soup = BeautifulSoup(wb_data.text,'lxml')
    links = soup.select("pre > a")
    with open(filename,"a+") as f:
        for link in links:
            target = base_url+link.get('href')
            f.write(target + "\n")

get_links("8abb71f4-d380-11e7-b3a1-8885306f7028",r"./8abb71f4-d380-11e7-b3a1-8885306f7028/urls.txt")

# %%
import pandas as pd
import json
import itertools

# %% [markdown]
# # 更换路径

# %%
# %cd 8abb71f4-d380-11e7-b3a1-8885306f7028
# Out:
# C:\Users\Kismet\Documents\我的坚果云\语忆科技有限公司\平台数据提取\8abb71f4-d380-11e7-b3a1-8885306f7028

# %% [markdown]
# # angry_res

# %%
with open(r"surprise_res.json","r") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data.to_excel("surprise_res.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # keyword_analyze

# %%
with open(r"keyword_analyze.json","r") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data = data.T
data.columns=[['value','词频']]
data['threshold'] = data['value']/data['词频']
data.to_excel("keyword_analyze.xlsx",encoding='gbk')

# %% [markdown]
# # keyword_mentioned_number

# %%
with open(r"keyword_mentioned_number.json","r") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data.to_excel("keyword_mentioned_number.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # keyword_relations

# %%
with open(r"keyword_relations.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data = data.stack().reset_index()
data.columns = [['level_0','level_1','point']]
data['频次'] = data.point.str[0]
data['threshold'] = data.point.str[1]/data['频次']
data.to_excel("keyword_relations.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # keywords_output

# %%
with open(r"keywords_output.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame.from_dict(file['keys'],orient='index')
df = pd.DataFrame(file['sorted'])
writer = pd.ExcelWriter('keywords_output.xlsx',engine='openpyxl')
data.to_excel(writer,'keys')
df.to_excel(writer,'sorted',index=False)
writer.save()

# %% [markdown]
# # slope_data_result

# %%
with open(r"slope_data_result.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data = data.stack().reset_index()
data.columns = [['level_0','level_1','point']]

df = pd.DataFrame(list(data.point))
c = pd.concat([data,df],axis=1)
c = c[['level_0','level_1','x','y']]
x_flat = pd.DataFrame([[i, x] for i, y in c['x'].apply(list).iteritems() for x in y], columns=list('IX'))
x_flat = x_flat.set_index('I')
xtemp=c[['level_0','level_1']].merge(x_flat, left_index=True, right_index=True)
y_flat = pd.DataFrame([[i, x] for i, y in c['y'].apply(list).iteritems() for x in y], columns=list('IY'))
y_flat = y_flat.set_index('I')
ytemp = c[['level_0','level_1']].merge(y_flat, left_index=True, right_index=True)
doc = xtemp.merge(ytemp,on=['level_0','level_1'],how='inner')
data.to_excel("slope_data_result.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # slope_emsemble

# %%
with open(r"slope_emsemble.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data = data.T
data.to_excel("slope_emsemble.xlsx",encoding='gbk')

# %% [markdown]
# # slope_result

# %%
with open(r"slope_result.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data = data.stack().reset_index()
data.columns = [['level_0','level_1','value']]
df = pd.DataFrame(list(data.value))
df = pd.concat([data,df],axis=1)
df = df[['level_0','level_1','intercept','slope','username']]
df.to_excel("slope_result.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # 负面情绪分布/平均应答时长分布/情绪浓度分布

# %%
with open(r"平均应答时长分布.json") as f:
    f = f.read()
    file = json.loads(f)
d = pd.DataFrame.from_dict(file,orient='index')
d.to_excel("平均应答时长分布.xlsx",encoding='gbk')

# %% [markdown]
# # 负面情绪排行/客服个人状态/平均应答时长排行/情绪浓度排行

# %%
with open(r"客服个人状态.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data.to_excel("客服个人状态.xlsx",encoding='gbk',index=False)

# %% [markdown]
# # 日会话量变化趋势

# %%
with open(r"日会话量变化趋势.json") as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame.from_dict(file,orient='index')
data.to_excel("日会话量变化趋势.xlsx",encoding='gbk')

# %% [markdown]
# # negative_cause

# %%
with open(r"negative_cause.json","r",encoding='utf-8') as f:
    f = f.read()
    file = json.loads(f)   
data = pd.DataFrame(file)
data = data.stack().reset_index()
data.columns=[['level_0','level_1','value']]
data['词频'] = data.value.str[1]
data['threshold'] = data.value.str[0]/data['词频']
data = data[['level_0','level_1','词频','threshold']]
data
# Out:
#     level_0 level_1   词频  threshold
# 0     12315      愤怒    5   2.706000
# 1       315      厌恶    2   3.063500
# 2       315      惊讶    1   1.661000
# 3       315      愤怒    8   2.755125
# 4       315      焦虑    2   1.862000
# 5      IMEI      愤怒    2   3.066500
# 6     Note6      惊讶    1   1.176000
# 7       P10      愤怒    3   2.131000
# 8        V9      厌恶    1   1.886000
# 9        V9      愤怒    3   2.056000
# 10       V9      焦虑    5   2.099400
# 11       VR      愤怒    1   3.180000
# 12    honor      愤怒    1   3.039000
# 13   iPhone      惊讶    1   1.365000
# 14   iPhone      愤怒   12   2.485333
# 15   iPhone      焦虑    5   3.642000
# 16    mate9      厌恶    1   1.886000
# 17    mate9      愤怒    4   2.157500
# 18     nano      愤怒    5   1.929600
# 19       下单      厌恶    1   5.646000
# 20       下单      惊讶  103   1.717757
# 21       下单      愤怒  530   1.618981
# 22       下单      焦虑  703   1.704819
# 23       下载      惊讶    2   1.620500
# 24       下载      愤怒   36   2.364389
# 25       下载      焦虑    4   1.100500
# 26       乐视      愤怒   12   2.247167
# 27     京东投诉      愤怒   15   2.843333
# 28       亮度      焦虑    3   1.864000
# 29       介入      厌恶    3   2.109000
# ..      ...     ...  ...        ...
# 419      音响      惊讶    3   1.519000
# 420      音响      愤怒    2   1.642500
# 421      音响      焦虑    5   2.426000
# 422      音箱      愤怒    2   1.382000
# 423      音量      惊讶    1   1.755000
# 424      音量      愤怒    3   1.675000
# 425      音量      焦虑   11   2.483000
# 426      预售      厌恶    1   2.228000
# 427      预售      惊讶   37   1.143973
# 428      预售      愤怒   91   1.265099
# 429      预售      焦虑  175   0.479029
# 430      预定      惊讶    4   2.373500
# 431      预定      愤怒    1   3.081000
# 432      预定      焦虑  178   0.464056
# 433      首付      厌恶   12   1.484000
# 434      首付      愤怒    9   1.626444
# 435     香槟金      惊讶    4   1.967000
# 436     香槟金      愤怒   17   2.097235
# 437      验货      厌恶    1   2.203000
# 438      验货      惊讶    2   1.554500
# 439      验货      愤怒   39   1.969974
# 440      验货      焦虑    6   2.047833
# 441      魅族      厌恶    1   2.681000
# 442      魅族      愤怒  101   1.968069
# 443      魅族      焦虑    5   2.262800
# 444      魅蓝      惊讶    1   1.207000
# 445      魅蓝      愤怒   57   2.162211
# 446      魅蓝      焦虑    1   1.322000
# 447     麦克风      愤怒    2   1.705000
# 448     麦克风      焦虑    6   3.137667
#
# [449 rows x 4 columns]

# %% [markdown]
# # kwfile

# %%
with open(r"kwfile.txt","r",encoding='utf-8') as f:
    f = f.read()
    file = json.loads(f)
data = pd.DataFrame(file)
data.to_excel("kwfile.xlsx",encoding='gbk',index = False)

# %% [markdown]
# # slope

# %%
data = pd.read_table("slope.txt")
data.to_excel("slope.xlsx",encoding='gbk',index = False)
